# %% [markdown]
# # Análise dos dados do campeonato brasileiro
# Dados desde 2006, adquiridos por meio do site da base dos dados, com origem do transfermarkt

# %%
import pandas as pd

# %%
Dados = pd.read_csv("Serie_A_BDD.csv")
Dados
# Out:
#       ano_campeonato        data horario  rodada  \
# 0               2006  2006-04-15   09:10       1
# 1               2006  2006-04-16   07:00       1
# 2               2006  2006-04-16   07:00       1
# 3               2006  2006-04-16   07:00       1
# 4               2006  2006-04-16   07:00       1
# ...              ...         ...     ...     ...
# 5695            2020  2021-02-26   01:30      38
# 5696            2020  2021-02-26   01:30      38
# 5697            2020  2021-02-26   01:30      38
# 5698            2020  2021-02-26   01:30      38
# 5699            2020  2021-02-26   01:30      38
#
#                                     estadio                     arbitro  \
# 0                    Estádio Alfredo Jaconi                         NaN
# 1            Estádio Olímpico Nilton Santos                         NaN
# 2     Estádio Municipal Anacleto Campanella                         NaN
# 3               Estádio José do Rego Maciel                         NaN
# ...

# %%
Dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5700 entries, 0 to 5699
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ano_campeonato            5700 non-null   int64
#  1   data                      5700 non-null   object
#  2   horario                   5700 non-null   object
#  3   rodada                    5700 non-null   int64
#  4   estadio                   5689 non-null   object
#  5   arbitro                   5320 non-null   object
#  6   publico                   5319 non-null   float64
#  7   publico_max               2783 non-null   float64
#  8   time_man                  5700 non-null   object
#  9   time_vis                  5700 non-null   object
#  10  tecnico_man               4932 non-null   object
#  11  tecnico_vis               4932 non-null   object
#  12  colocacao_man             5320 non-null   float64
# ...

# %%
Dados.describe()
# Out:
#        ano_campeonato       rodada       publico   publico_max  colocacao_man  \
# count     5700.000000  5700.000000   5319.000000   2783.000000    5320.000000
# mean      2013.000000    19.500000  15147.530739  43793.607977      10.647932
# std          4.320873    10.966818  12882.498870  19550.331521       5.751310
# min       2006.000000     1.000000      0.000000   8000.000000       1.000000
# 25%       2009.000000    10.000000   6144.500000  24584.000000       6.000000
# 50%       2013.000000    19.500000  12281.000000  43600.000000      11.000000
# 75%       2017.000000    29.000000  20814.000000  57483.000000      16.000000
# max       2020.000000    38.000000  82044.000000  87101.000000      20.000000
#
#        colocacao_vis  valor_equipe_titular_man  valor_equipe_titular_vis  \
# count    5320.000000              4.932000e+03              4.932000e+03
# mean       10.352068              1.690261e+07              1.649931e+07
# ...
